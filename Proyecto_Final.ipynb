# %% [markdown]
# <a href="https://colab.research.google.com/github/RodrigoCG1281/Proyecto_Ciencia_de_datos/blob/main/Proyecto_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DELITOS DENUNCIADOS POR CIBERDELINCUENCIA
# ## INTEGRANTES:
#
# - CONDORI GUTIERREZ RODRIGO BERNARDO
# - VILCA QUISPE OSCAR EDY

# %%
print("Hola")
# Out:
# Hola

# %%
print("Probando 1")
# Out:
# Probando 1

# %%
print("Prueba git")
# Out:
# Prueba git
